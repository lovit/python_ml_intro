# %%
import numpy as np
from soydata.data.clustering import make_circular_clusters
from soydata.visualize import scatterplot
from soydata.visualize import use_notebook

use_notebook()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
X, labels = make_circular_clusters(n_clusters=10, r_min=0.05, r_max=0.15,
    equal_density=True, noise=0.05, seed=0, size_min=150, size_max=250)

data_indices = np.where(labels >= 0)[0]
noise_indices = np.where(labels == -1)[0]

p = scatterplot(X[data_indices], labels=labels, size=3, title='Circular clusters',
    show_inline=False, toolbar_location=None)
p = scatterplot(X[noise_indices], p=p, color='lightgrey')
# Out:
#   <div class="bk-root" id="102139ab-ba1b-4388-bb82-64dd4fd46f61" data-root-id="1002"></div>

# %%
from kmeans_from_scratch import kmeans

centers, labels = kmeans(X, n_clusters=15, metric='euclidean', verbose=True)
# Out:
# [iter: 1/10] #changes: 1912, diff: 0.05754, inner: 0.1054
# [iter: 2/10] #changes: 195, diff: 0.01241, inner: 0.07894
# [iter: 3/10] #changes: 72, diff: 0.007141, inner: 0.07742
# [iter: 4/10] #changes: 49, diff: 0.005014, inner: 0.07723
# [iter: 5/10] #changes: 54, diff: 0.007459, inner: 0.07678
# [iter: 6/10] #changes: 47, diff: 0.006924, inner: 0.0751
# [iter: 7/10] #changes: 52, diff: 0.005369, inner: 0.0731
# [iter: 8/10] #changes: 38, diff: 0.003015, inner: 0.07202
# [iter: 9/10] #changes: 32, diff: 0.00288, inner: 0.07162
# [iter: 10/10] #changes: 23, diff: 0.001997, inner: 0.07141

# %%
data_indices = np.where(labels >= 0)[0]
noise_indices = np.where(labels == -1)[0]

p = scatterplot(X[data_indices], labels=labels, size=3, title='Circular clusters',
    show_inline=False, toolbar_location=None)
p = scatterplot(X[noise_indices], p=p, color='lightgrey')
# Out:
#   <div class="bk-root" id="7423d631-0f5e-4216-b712-d9212a27cf0f" data-root-id="1114"></div>
