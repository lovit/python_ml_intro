# %% [markdown]
# Python >= 3.7.0 을 기준으로 작성된 튜토리얼입니다.

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=7, micro=1, releaselevel='final', serial=0)

# %% [markdown]
# ## IPython notebook

# %%
from IPython.display import Image

Image('./figures/notebook_shortcut.png')
