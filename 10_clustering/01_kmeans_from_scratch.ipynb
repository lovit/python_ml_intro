# %% [markdown]
# 앞서 dev tutorial 에서 만든 함수를 `kmeans_from_scratch` 패키지에 정리해뒀습니다. 해당 패키지를 테스트해봅니다.

# %%
import numpy as np
from soydata.data.clustering import make_circular_clusters
from soydata.visualize import scatterplot
from soydata.visualize import use_notebook

use_notebook()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
X, labels = make_circular_clusters(n_clusters=10, r_min=0.05, r_max=0.15,
    equal_density=True, noise=0.05, seed=0, size_min=150, size_max=250)

data_indices = np.where(labels >= 0)[0]
noise_indices = np.where(labels == -1)[0]

p = scatterplot(X[data_indices], labels=labels, size=3, title='Circular clusters',
    show_inline=False, toolbar_location=None)
p = scatterplot(X[noise_indices], p=p, color='lightgrey')
# Out:
#   <div class="bk-root" id="15b9d61d-28f5-45a9-8e79-35b6edf72e05" data-root-id="1002"></div>

# %%
from kmeans_from_scratch import kmeans

centers, labels = kmeans(X, n_clusters=15, metric='euclidean', verbose=True)
# Out:
# [iter: 1/10] #changes: 1912, diff: 0.04012, inner: 0.08887
# [iter: 2/10] #changes: 207, diff: 0.01602, inner: 0.07514
# [iter: 3/10] #changes: 101, diff: 0.008344, inner: 0.07247
# [iter: 4/10] #changes: 51, diff: 0.004682, inner: 0.07182
# [iter: 5/10] #changes: 37, diff: 0.003331, inner: 0.07169
# [iter: 6/10] #changes: 31, diff: 0.003017, inner: 0.07164
# [iter: 7/10] #changes: 26, diff: 0.002651, inner: 0.07163
# [iter: 8/10] #changes: 17, diff: 0.002129, inner: 0.0716
# [iter: 9/10] #changes: 15, diff: 0.00185, inner: 0.07161
# [iter: 10/10] #changes: 10, diff: 0.000986, inner: 0.07164

# %%
data_indices = np.where(labels >= 0)[0]
noise_indices = np.where(labels == -1)[0]

p = scatterplot(X[data_indices], labels=labels, size=3, title='Circular clusters',
    show_inline=False, toolbar_location=None)
p = scatterplot(X[noise_indices], p=p, color='lightgrey')
# Out:
#   <div class="bk-root" id="63a57ef6-31e8-4de7-baa9-671a9ea61760" data-root-id="1114"></div>
