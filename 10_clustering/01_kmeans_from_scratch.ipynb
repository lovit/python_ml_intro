# %% [markdown]
# 앞서 dev tutorial 에서 만든 함수를 `kmeans_from_scratch` 패키지에 정리해뒀습니다. 해당 패키지를 테스트해봅니다.

# %%
import numpy as np
from soydata.data.clustering import make_circular_clusters
from soydata.visualize import scatterplot
from soydata.visualize import use_notebook

use_notebook()
# Out:
# /usr/local/var/pyenv/versions/3.7.7/envs/lovit3.7.7/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
X, labels = make_circular_clusters(n_clusters=10, r_min=0.05, r_max=0.15,
    equal_density=True, noise=0.05, seed=0, size_min=150, size_max=250)

data_indices = np.where(labels >= 0)[0]
noise_indices = np.where(labels == -1)[0]

p = scatterplot(X[data_indices], labels=labels, size=3, title='Circular clusters',
    show_inline=False, toolbar_location=None)
p = scatterplot(X[noise_indices], p=p, color='lightgrey')
# Out:
#   <div class="bk-root" id="27c6eca1-e6e9-4b1c-8147-d839f7769467" data-root-id="1002"></div>

# %%
from kmeans_from_scratch import kmeans

centers, labels = kmeans(X, n_clusters=15, metric='euclidean', verbose=True)
# Out:
# [iter: 1/10] #changes: 1912, diff: 0.05068, inner: 0.09244
# [iter: 2/10] #changes: 229, diff: 0.01828, inner: 0.07726
# [iter: 3/10] #changes: 160, diff: 0.01402, inner: 0.07391
# [iter: 4/10] #changes: 93, diff: 0.01001, inner: 0.07154
# [iter: 5/10] #changes: 51, diff: 0.01012, inner: 0.07099
# [iter: 6/10] #changes: 27, diff: 0.004087, inner: 0.07057
# [iter: 7/10] #changes: 20, diff: 0.003404, inner: 0.07049
# [iter: 8/10] #changes: 16, diff: 0.002491, inner: 0.07042
# [iter: 9/10] #changes: 16, diff: 0.001147, inner: 0.07036
# [iter: 10/10] #changes: 19, diff: 0.001723, inner: 0.07028

# %%
data_indices = np.where(labels >= 0)[0]
noise_indices = np.where(labels == -1)[0]

p = scatterplot(X[data_indices], labels=labels, size=3, title='Circular clusters',
    show_inline=False, toolbar_location=None)
p = scatterplot(X[noise_indices], p=p, color='lightgrey')
# Out:
#   <div class="bk-root" id="1fc5fa50-15d4-46ab-9aaa-c3080cb585c0" data-root-id="1114"></div>
